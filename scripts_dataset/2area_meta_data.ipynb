# %%
import pandas as pd

# %%
df = pd.read_csv("../data/area_meta.csv")
df = df.drop(columns=["category", "is_percentage", "start_date", "end_date"])

df_out = df.pivot(
    index=["area_id"], 
    columns="variable", 
    values="value"
).reset_index()

df_out.columns.name = None

df_out = df_out.fillna(0)

# %%
df_out['total_male_population'] = df_out['Younger than 5 years (Total male population)'] + df_out['From 5 to 9 years (Total male population)'] + df_out['From 10 to 14 years (Total male population)'] + df_out['From 15 to 19 years (Total male population)']+ df_out['From 20 to 24 years (Total male population)'] + df_out['From 25 to 29 years (Total male population)'] + df_out['From 30 to 34 years (Total male population)'] + df_out['From 35 to 39 years (Total male population)'] + df_out['From 40 to 44 years (Total male population)'] + df_out['From 45 to 49 years (Total male population)'] + df_out['From 50 to 54 years (Total male population)']+ df_out['From 55 to 59 years (Total male population)'] + df_out['From 60 to 64 years (Total male population)'] + df_out['From 65 to 69 years (Total male population)'] + df_out['From 70 to 74 years (Total male population)'] + df_out['From 75 to 79 years (Total male population)'] + df_out['From 80 to 84 years (Total male population)'] + df_out['From 85 to 89 years (Total male population)'] + df_out['From 90 to 94 years (Total male population)'] + df_out['From 95 to 99 years (Total male population)']+ df_out['100 years and older (Total male population)']
df_out['total_female_population'] = df_out['Younger than 5 years (Total female population)'] + df_out['From 5 to 9 years (Total female population)'] + df_out['From 10 to 14 years (Total female population)'] + df_out['From 15 to 19 years (Total female population)']+ df_out['From 20 to 24 years (Total female population)'] + df_out['From 25 to 29 years (Total female population)'] + df_out['From 30 to 34 years (Total female population)'] + df_out['From 35 to 39 years (Total female population)'] + df_out['From 40 to 44 years (Total female population)'] + df_out['From 45 to 49 years (Total female population)'] + df_out['From 50 to 54 years (Total female population)']+ df_out['From 55 to 59 years (Total female population)'] + df_out['From 60 to 64 years (Total female population)'] + df_out['From 65 to 69 years (Total female population)'] + df_out['From 70 to 74 years (Total female population)'] + df_out['From 75 to 79 years (Total female population)'] + df_out['From 80 to 84 years (Total female population)'] + df_out['From 85 to 89 years (Total female population)'] + df_out['From 90 to 94 years (Total female population)'] + df_out['From 95 to 99 years (Total female population)']+ df_out['100 years and older (Total female population)']
df_out['total_population'] = df_out['total_male_population'] + df_out['total_female_population']

df_out['20-34 (male)'] = df_out['From 20 to 24 years (Total male population)'] + df_out['From 25 to 29 years (Total male population)'] + df_out['From 30 to 34 years (Total male population)']
df_out['35-54 (male)'] = df_out['From 35 to 39 years (Total male population)'] + df_out['From 40 to 44 years (Total male population)'] + df_out['From 45 to 49 years (Total male population)'] + df_out['From 50 to 54 years (Total male population)']
df_out['55-69 (male)'] = df_out['From 55 to 59 years (Total male population)'] + df_out['From 60 to 64 years (Total male population)'] + df_out['From 65 to 69 years (Total male population)']
df_out['70+ (male)'] = df_out['From 70 to 74 years (Total male population)'] + df_out['From 75 to 79 years (Total male population)'] + df_out['From 80 to 84 years (Total male population)'] + df_out['From 85 to 89 years (Total male population)'] + df_out['From 90 to 94 years (Total male population)'] + df_out['From 95 to 99 years (Total male population)']

df_out['20-34 (female)'] = df_out['From 20 to 24 years (Total female population)'] + df_out['From 25 to 29 years (Total female population)'] + df_out['From 30 to 34 years (Total female population)']
df_out['35-54 (female)'] = df_out['From 35 to 39 years (Total female population)'] + df_out['From 40 to 44 years (Total female population)'] + df_out['From 45 to 49 years (Total female population)'] + df_out['From 50 to 54 years (Total female population)']
df_out['55-69 (female)'] = df_out['From 55 to 59 years (Total female population)'] + df_out['From 60 to 64 years (Total female population)'] + df_out['From 65 to 69 years (Total female population)']
df_out['70+ (female)'] = df_out['From 70 to 74 years (Total female population)'] + df_out['From 75 to 79 years (Total female population)'] + df_out['From 80 to 84 years (Total female population)'] + df_out['From 85 to 89 years (Total female population)'] + df_out['From 90 to 94 years (Total female population)'] + df_out['From 95 to 99 years (Total female population)']

df_out['6-8 persons'] = df_out['6 persons'] + df_out['7 persons'] + df_out['8 persons']
df_out['9+ persons'] = df_out['9 persons'] + df_out['10 persons'] + df_out['11 persons or more']

df_out['Students'] = df_out['Students (Total male population)'] + df_out['Students (Total female population)']
df_out['Employed'] = df_out['Employed (Total male population)'] + df_out['Employed (Total female population)']
df_out['Unemployed'] = df_out['Unemployed (Total male population)'] + df_out['Unemployed (Total female population)']
df_out['Pensioners or recipients'] = df_out['Pensioners or recipients of capital income (Total male population)'] + df_out['Pensioners or recipients of capital income (Total female population)']
df_out['Persons under the national minimum age for economic activity'] = df_out['Persons under the national minimum age for economic activity (Total male population)'] + df_out['Persons under the national minimum age for economic activity (Total female population)']

df_out['No diploma or certificate'] = df_out['No diploma or certificate (ISCED 0) (Total female population)'] + df_out['No diploma or certificate (ISCED 0) (Total male population)']
df_out['Primary education'] = df_out['Primary education (ISCED 1) (Total female population)'] + df_out['Primary education (ISCED 1) (Total male population)']
df_out['Lower secondary education'] = df_out['Lower secondary education (ISCED 2) (Total female population)'] + df_out['Lower secondary education (ISCED 2) (Total male population)']
df_out['Upper secondary education'] = df_out['Upper secondary education (ISCED 3) (Total female population)'] + df_out['Upper secondary education (ISCED 3) (Total male population)']
df_out['Post-secondary non tertiary education'] = df_out['Post-secondary non tertiary education (ISCED 4) (Total female population)'] + df_out['Post-secondary non tertiary education (ISCED 4) (Total male population)']
df_out['Short cycle Tertiary education'] = df_out['Short cycle Tertiary education (ISCED 5) (Total female population)'] + df_out['Short cycle Tertiary education (ISCED 5) (Total male population)']
df_out['Bachelors or equivalent'] = df_out['Bachelors or equivalent (ISCED 6) (Total female population)'] + df_out['Bachelors or equivalent (ISCED 6) (Total male population)']
df_out['Masters or equivalent'] = df_out['Masters or equivalent (ISCED 7) (Total female population)'] + df_out['Masters or equivalent (ISCED 7) (Total male population)']
df_out['Doctorate or equivalent'] = df_out['Doctorate or equivalent (ISCED 8) (Total female population)'] + df_out['Doctorate or equivalent (ISCED 8) (Total male population)']

# %%
column_not_used = [
    '6 persons', '7 persons', '8 persons', '9 persons', '10 persons', '11 persons or more',
    
    'From 20 to 24 years (Total female population)', 'From 20 to 24 years (Total male population)',
    'From 25 to 29 years (Total female population)', 'From 25 to 29 years (Total male population)',
    'From 30 to 34 years (Total female population)', 'From 30 to 34 years (Total male population)',
    'From 35 to 39 years (Total female population)', 'From 35 to 39 years (Total male population)',
    'From 40 to 44 years (Total female population)', 'From 40 to 44 years (Total male population)',
    'From 45 to 49 years (Total female population)', 'From 45 to 49 years (Total male population)',
    'From 50 to 54 years (Total female population)', 'From 50 to 54 years (Total male population)',
    'From 55 to 59 years (Total female population)', 'From 55 to 59 years (Total male population)',
    'From 60 to 64 years (Total female population)', 'From 60 to 64 years (Total male population)',
    'From 65 to 69 years (Total female population)', 'From 65 to 69 years (Total male population)',
    'From 70 to 74 years (Total female population)', 'From 70 to 74 years (Total male population)',
    'From 75 to 79 years (Total female population)', 'From 75 to 79 years (Total male population)',
    'From 80 to 84 years (Total female population)', 'From 80 to 84 years (Total male population)',
    'From 85 to 89 years (Total female population)', 'From 85 to 89 years (Total male population)',
    'From 90 to 94 years (Total female population)', 'From 90 to 94 years (Total male population)',
    'From 95 to 99 years (Total female population)', 'From 95 to 99 years (Total male population)',
    '100 years and older (Total female population)', '100 years and older (Total male population)',

    'No diploma or certificate (ISCED 0) (Total female population)', 'No diploma or certificate (ISCED 0) (Total male population)',
    'Primary education (ISCED 1) (Total female population)', 'Primary education (ISCED 1) (Total male population)',
    'Lower secondary education (ISCED 2) (Total female population)', 'Lower secondary education (ISCED 2) (Total male population)',
    'Upper secondary education (ISCED 3) (Total female population)', 'Upper secondary education (ISCED 3) (Total male population)',
    'Post-secondary non tertiary education (ISCED 4) (Total female population)', 'Post-secondary non tertiary education (ISCED 4) (Total male population)',
    'Short cycle Tertiary education (ISCED 5) (Total female population)', 'Short cycle Tertiary education (ISCED 5) (Total male population)',
    'Bachelors or equivalent (ISCED 6) (Total female population)', 'Bachelors or equivalent (ISCED 6) (Total male population)',
    'Masters or equivalent (ISCED 7) (Total female population)', 'Masters or equivalent (ISCED 7) (Total male population)',
    'Doctorate or equivalent (ISCED 8) (Total female population)', 'Doctorate or equivalent (ISCED 8) (Total male population)',
    
    'Not applicable (for persons younger than 15) (Total female population)', 'Not applicable (for persons younger than 15) (Total male population)',
    'Not specified (for persons 15 years or older) (Total female population)', 'Not specified (for persons 15 years or older) (Total male population)',
    'Others (Total female population)', 'Others (Total male population)',

    'Students (Total female population)', 'Students (Total male population)',
    'Employed (Total female population)', 'Employed (Total male population)',
    'Unemployed (Total female population)', 'Unemployed (Total male population)',
    'Pensioners or recipients of capital income (Total female population)', 'Pensioners or recipients of capital income (Total male population)',
    'Persons under the national minimum age for economic activity (Total female population)', 'Persons under the national minimum age for economic activity (Total male population)',
    ]

# %%
area_meta_df = df_out.drop(columns=column_not_used)

area_df = pd.read_csv("../data/areas.csv")
area_df = area_df.drop(columns=["parent_area_id", "start_date", "end_date", "name"])

result = pd.merge(area_df, area_meta_df, on="area_id")

result.to_csv("area_meta_cleaned.csv", index=False)

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/area_meta.csv")
df = df.drop(columns=["category", "is_percentage", "start_date", "end_date"])

# %%
# df["category"].value_counts()

# %%
df_out = df.pivot(
    index=["area_id"], 
    columns="variable", 
    values="value"
).reset_index()

df_out.columns.name = None

# %%
df_out.shape
# Out:
# (19365, 88)

# %%
df_out = df_out.fillna(0)

# %%
df_out.tail(5)
# Out:
#              area_id  1 person  10 persons  \
# 19360  1-6-93090G191       5.0         0.0
# 19361  1-6-93090H000      47.0         0.0
# 19362  1-6-93090H012       4.0         0.0
# 19363  1-6-93090H063       5.0         0.0
# 19364  1-6-93090H091       7.0         0.0
#
#        100 years and older (Total female population)  \
# 19360                                            0.0
# 19361                                            0.0
# 19362                                            0.0
# 19363                                            0.0
# 19364                                            0.0
#
#        100 years and older (Total male population)  11 persons or more  \
# 19360                                          0.0                 0.0
# 19361                                          0.0                 0.0
# 19362                                          0.0                 0.0
# 19363                                          0.0                 0.0
# ...

# %%
pd.set_option('display.max_columns', None)
print(df_out.columns.tolist())
# Out:
# ['area_id', '1 person', '10 persons', '100 years and older (Total female population)', '100 years and older (Total male population)', '11 persons or more', '2 persons', '3 persons', '4 persons', '5 persons', '6 persons', '7 persons', '8 persons', '9 persons', 'Bachelors or equivalent (ISCED 6) (Total female population)', 'Bachelors or equivalent (ISCED 6) (Total male population)', 'Doctorate or equivalent (ISCED 8) (Total female population)', 'Doctorate or equivalent (ISCED 8) (Total male population)', 'Employed (Total female population)', 'Employed (Total male population)', 'From 10 to 14 years (Total female population)', 'From 10 to 14 years (Total male population)', 'From 15 to 19 years (Total female population)', 'From 15 to 19 years (Total male population)', 'From 20 to 24 years (Total female population)', 'From 20 to 24 years (Total male population)', 'From 25 to 29 years (Total female population)', 'From 25 to 29 years (Total male population)', 'From 30 to 34 years (Total fema
# ...

# %%
df_out['total_male_population'] = df_out['Younger than 5 years (Total male population)'] + df_out['From 5 to 9 years (Total male population)'] + df_out['From 10 to 14 years (Total male population)'] + df_out['From 15 to 19 years (Total male population)']+ df_out['From 20 to 24 years (Total male population)'] + df_out['From 25 to 29 years (Total male population)'] + df_out['From 30 to 34 years (Total male population)'] + df_out['From 35 to 39 years (Total male population)'] + df_out['From 40 to 44 years (Total male population)'] + df_out['From 45 to 49 years (Total male population)'] + df_out['From 50 to 54 years (Total male population)']+ df_out['From 55 to 59 years (Total male population)'] + df_out['From 60 to 64 years (Total male population)'] + df_out['From 65 to 69 years (Total male population)'] + df_out['From 70 to 74 years (Total male population)'] + df_out['From 75 to 79 years (Total male population)'] + df_out['From 80 to 84 years (Total male population)'] + df_out['From 85 to 89 years (Total male population)'] + df_out['From 90 to 94 years (Total male population)'] + df_out['From 95 to 99 years (Total male population)']+ df_out['100 years and older (Total male population)']
df_out['total_female_population'] = df_out['Younger than 5 years (Total female population)'] + df_out['From 5 to 9 years (Total female population)'] + df_out['From 10 to 14 years (Total female population)'] + df_out['From 15 to 19 years (Total female population)']+ df_out['From 20 to 24 years (Total female population)'] + df_out['From 25 to 29 years (Total female population)'] + df_out['From 30 to 34 years (Total female population)'] + df_out['From 35 to 39 years (Total female population)'] + df_out['From 40 to 44 years (Total female population)'] + df_out['From 45 to 49 years (Total female population)'] + df_out['From 50 to 54 years (Total female population)']+ df_out['From 55 to 59 years (Total female population)'] + df_out['From 60 to 64 years (Total female population)'] + df_out['From 65 to 69 years (Total female population)'] + df_out['From 70 to 74 years (Total female population)'] + df_out['From 75 to 79 years (Total female population)'] + df_out['From 80 to 84 years (Total female population)'] + df_out['From 85 to 89 years (Total female population)'] + df_out['From 90 to 94 years (Total female population)'] + df_out['From 95 to 99 years (Total female population)']+ df_out['100 years and older (Total female population)']
df_out['total_population'] = df_out['total_male_population'] + df_out['total_female_population']

df_out['20-34 (male)'] = df_out['From 20 to 24 years (Total male population)'] + df_out['From 25 to 29 years (Total male population)'] + df_out['From 30 to 34 years (Total male population)']
df_out['35-54 (male)'] = df_out['From 35 to 39 years (Total male population)'] + df_out['From 40 to 44 years (Total male population)'] + df_out['From 45 to 49 years (Total male population)'] + df_out['From 50 to 54 years (Total male population)']
df_out['55-69 (male)'] = df_out['From 55 to 59 years (Total male population)'] + df_out['From 60 to 64 years (Total male population)'] + df_out['From 65 to 69 years (Total male population)']
df_out['70+ (male)'] = df_out['From 70 to 74 years (Total male population)'] + df_out['From 75 to 79 years (Total male population)'] + df_out['From 80 to 84 years (Total male population)'] + df_out['From 85 to 89 years (Total male population)'] + df_out['From 90 to 94 years (Total male population)'] + df_out['From 95 to 99 years (Total male population)']

df_out['20-34 (female)'] = df_out['From 20 to 24 years (Total female population)'] + df_out['From 25 to 29 years (Total female population)'] + df_out['From 30 to 34 years (Total female population)']
df_out['35-54 (female)'] = df_out['From 35 to 39 years (Total female population)'] + df_out['From 40 to 44 years (Total female population)'] + df_out['From 45 to 49 years (Total female population)'] + df_out['From 50 to 54 years (Total female population)']
df_out['55-69 (female)'] = df_out['From 55 to 59 years (Total female population)'] + df_out['From 60 to 64 years (Total female population)'] + df_out['From 65 to 69 years (Total female population)']
df_out['70+ (female)'] = df_out['From 70 to 74 years (Total female population)'] + df_out['From 75 to 79 years (Total female population)'] + df_out['From 80 to 84 years (Total female population)'] + df_out['From 85 to 89 years (Total female population)'] + df_out['From 90 to 94 years (Total female population)'] + df_out['From 95 to 99 years (Total female population)']

df_out['6-8 persons'] = df_out['6 persons'] + df_out['7 persons'] + df_out['8 persons']
df_out['9+ persons'] = df_out['9 persons'] + df_out['10 persons'] + df_out['11 persons or more']

df_out['Students'] = df_out['Students (Total male population)'] + df_out['Students (Total female population)']
df_out['Employed'] = df_out['Employed (Total male population)'] + df_out['Employed (Total female population)']
df_out['Unemployed'] = df_out['Unemployed (Total male population)'] + df_out['Unemployed (Total female population)']
df_out['Pensioners or recipients'] = df_out['Pensioners or recipients of capital income (Total male population)'] + df_out['Pensioners or recipients of capital income (Total female population)']
df_out['Persons under the national minimum age for economic activity'] = df_out['Persons under the national minimum age for economic activity (Total male population)'] + df_out['Persons under the national minimum age for economic activity (Total female population)']

df_out['No diploma or certificate'] = df_out['No diploma or certificate (ISCED 0) (Total female population)'] + df_out['No diploma or certificate (ISCED 0) (Total male population)']
df_out['Primary education'] = df_out['Primary education (ISCED 1) (Total female population)'] + df_out['Primary education (ISCED 1) (Total male population)']
df_out['Lower secondary education'] = df_out['Lower secondary education (ISCED 2) (Total female population)'] + df_out['Lower secondary education (ISCED 2) (Total male population)']
df_out['Upper secondary education'] = df_out['Upper secondary education (ISCED 3) (Total female population)'] + df_out['Upper secondary education (ISCED 3) (Total male population)']
df_out['Post-secondary non tertiary education'] = df_out['Post-secondary non tertiary education (ISCED 4) (Total female population)'] + df_out['Post-secondary non tertiary education (ISCED 4) (Total male population)']
df_out['Short cycle Tertiary education'] = df_out['Short cycle Tertiary education (ISCED 5) (Total female population)'] + df_out['Short cycle Tertiary education (ISCED 5) (Total male population)']
df_out['Bachelors or equivalent'] = df_out['Bachelors or equivalent (ISCED 6) (Total female population)'] + df_out['Bachelors or equivalent (ISCED 6) (Total male population)']
df_out['Masters or equivalent'] = df_out['Masters or equivalent (ISCED 7) (Total female population)'] + df_out['Masters or equivalent (ISCED 7) (Total male population)']
df_out['Doctorate or equivalent'] = df_out['Doctorate or equivalent (ISCED 8) (Total female population)'] + df_out['Doctorate or equivalent (ISCED 8) (Total male population)']

# %%
column_not_used = [
    '6 persons', '7 persons', '8 persons', '9 persons', '10 persons', '11 persons or more',
    
    'From 20 to 24 years (Total female population)', 'From 20 to 24 years (Total male population)',
    'From 25 to 29 years (Total female population)', 'From 25 to 29 years (Total male population)',
    'From 30 to 34 years (Total female population)', 'From 30 to 34 years (Total male population)',
    'From 35 to 39 years (Total female population)', 'From 35 to 39 years (Total male population)',
    'From 40 to 44 years (Total female population)', 'From 40 to 44 years (Total male population)',
    'From 45 to 49 years (Total female population)', 'From 45 to 49 years (Total male population)',
    'From 50 to 54 years (Total female population)', 'From 50 to 54 years (Total male population)',
    'From 55 to 59 years (Total female population)', 'From 55 to 59 years (Total male population)',
    'From 60 to 64 years (Total female population)', 'From 60 to 64 years (Total male population)',
    'From 65 to 69 years (Total female population)', 'From 65 to 69 years (Total male population)',
    'From 70 to 74 years (Total female population)', 'From 70 to 74 years (Total male population)',
    'From 75 to 79 years (Total female population)', 'From 75 to 79 years (Total male population)',
    'From 80 to 84 years (Total female population)', 'From 80 to 84 years (Total male population)',
    'From 85 to 89 years (Total female population)', 'From 85 to 89 years (Total male population)',
    'From 90 to 94 years (Total female population)', 'From 90 to 94 years (Total male population)',
    'From 95 to 99 years (Total female population)', 'From 95 to 99 years (Total male population)',
    '100 years and older (Total female population)', '100 years and older (Total male population)',

    'No diploma or certificate (ISCED 0) (Total female population)', 'No diploma or certificate (ISCED 0) (Total male population)',
    'Primary education (ISCED 1) (Total female population)', 'Primary education (ISCED 1) (Total male population)',
    'Lower secondary education (ISCED 2) (Total female population)', 'Lower secondary education (ISCED 2) (Total male population)',
    'Upper secondary education (ISCED 3) (Total female population)', 'Upper secondary education (ISCED 3) (Total male population)',
    'Post-secondary non tertiary education (ISCED 4) (Total female population)', 'Post-secondary non tertiary education (ISCED 4) (Total male population)',
    'Short cycle Tertiary education (ISCED 5) (Total female population)', 'Short cycle Tertiary education (ISCED 5) (Total male population)',
    'Bachelors or equivalent (ISCED 6) (Total female population)', 'Bachelors or equivalent (ISCED 6) (Total male population)',
    'Masters or equivalent (ISCED 7) (Total female population)', 'Masters or equivalent (ISCED 7) (Total male population)',
    'Doctorate or equivalent (ISCED 8) (Total female population)', 'Doctorate or equivalent (ISCED 8) (Total male population)',
    
    'Not applicable (for persons younger than 15) (Total female population)', 'Not applicable (for persons younger than 15) (Total male population)',
    'Not specified (for persons 15 years or older) (Total female population)', 'Not specified (for persons 15 years or older) (Total male population)',
    'Others (Total female population)', 'Others (Total male population)',

    'Students (Total female population)', 'Students (Total male population)',
    'Employed (Total female population)', 'Employed (Total male population)',
    'Unemployed (Total female population)', 'Unemployed (Total male population)',
    'Pensioners or recipients of capital income (Total female population)', 'Pensioners or recipients of capital income (Total male population)',
    'Persons under the national minimum age for economic activity (Total female population)', 'Persons under the national minimum age for economic activity (Total male population)',
    ]

# %%
df_out = df_out.drop(columns=column_not_used)

# %%
df_out.shape
# Out:
# (19365, 41)

# %%
df_out.to_csv("area_meta_cleaned.csv", index=False)
